# %% [markdown]
# <a href="https://colab.research.google.com/github/anapitalai/gee/blob/main/nanoGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch numpy transformers datasets tiktoken wandb tqdm

# %%
# !git clone  https://github.com/karpathy/nanoGPT.git
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 686, done.
# remote: Total 686 (delta 0), reused 0 (delta 0), pack-reused 686 (from 1)
# Receiving objects: 100% (686/686), 954.04 KiB | 20.74 MiB/s, done.
# Resolving deltas: 100% (387/387), done.

# %%
# !python data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 115,852
# all the unique characters:
#  !(),-.0123456789:;?ABDEGIKLMNOPRSTUVabcdefghiklmnoprstuvwy© ‑–﻿
# vocab size: 65
# train has 104,266 tokens
# val has 11,586 tokens

# %%
vocab size: 65
train has 1,003,854 tokens
val has 111,540 tokens

# %%
import os

os.chdir('/content/nanoGPT')
print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: /content/nanoGPT

# %%
import torch._dynamo
torch._dynamo.config.suppress_errors = True
# !python train.py config/train_shakespeare_char.py --batch_size=12 --compile=False
# Out:
# Overriding config with config/train_shakespeare_char.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-shakespeare-char'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'shakespeare_char'
# gradient_accumulation_steps = 1
# batch_size = 64
# block_size = 256 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 6
# n_head = 6
# n_embd = 384
# dropout = 0.2
#
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 5000
# lr_decay_iters = 5000 # make equal to max_iters usually
# ...

# %%
# !python sample.py --out_dir=out-shakespeare-char
# Out:
# Overriding: out_dir = out-shakespeare-char
# number of parameters: 10.65M
# Loading meta from data/shakespeare_char/meta.pkl...
#
# 41Ma ra tarai Kanaan dia ga varagur me dia ga vana upi diat a varubu me; tago dia ga pait  ra umana papar a  lavurua na  marmar na tarai Seba ta ra lualuana, ma  ra tarai dia ga tur ta ra mataniolo  i ra umana pa diat.  25Ma ra umana dia ga vana urama, ma dia ga tul tar ra lima i diat, ma i diat tama ra umana niuruna, ma ra kavuna tava  i ki ta ra lavurua na viviri pire diat diat mulai dia ga ka  na vilavilik ure ra pal Iuda. 3Ma dia ga ki livuan tadav ra  pal kai Israel  ta ra umana gunan kikil
# ---------------
#
# ...
